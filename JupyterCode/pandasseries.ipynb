# %%
import pandas as pd
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, 30, 35, 40, 45],
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Miami"]
}
df = pd.DataFrame(data)

# %%
df.iloc[2]
# Out:
# Name    Charlie
# Age          35
# City    Chicago
# Name: 2, dtype: object

# %%
df.loc[(df["Age"]>25)]
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eve   45        Miami

# %%
city = pd.Series("City")
city.head(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24440\847525397.py in ?()
# ----> 1 city = df.Series("City")
#       2 city.head(2)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Series'

# %%
type(df["City"])
# Out:
# pandas.core.series.Series

# %%
city =df["City"]
print(city)
# Out:
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# 4          Miami
# Name: City, dtype: object

# %%
city_list = list(df["City"])
Person_Name = list(df["Name"])
new_series = pd.Series(data=Person_Name, index = city_list)
new_series
# Out:
# New York         Alice
# Los Angeles        Bob
# Chicago        Charlie
# Houston          David
# Miami              Eve
# dtype: object

# %%
print(new_series["Miami"])
# Out:
# Eve

# %%
#we can extract a series from dataframe
#while reading a file, we can create a series just by reading a column or using index_col method as well.
pokemon =
